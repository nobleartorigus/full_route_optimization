# %%
from sys import path
path.insert(0,'../../python')
from map_utils import *
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster,HeatMap, Fullscreen
from folium import plugins
import re
from async_request import make_request
from requests import Session

# %%
associates = pd.read_excel('../../data/aguascalientes/Direct headcount with ZIP codes 051219.xlsx',dtype=str)

# %%
associates.head()
# Out:
#    Nº pers.               Número de personal Cód.postal
# 0  62000048            MALDONADO ZAMORA JOSE      20324
# 1  62000060  BENITEZ MEDINA BRAYAN ALEJANDRO      20925
# 2  62000191     VILCHIS PAULINO MIGUEL ANGEL      20196
# 3  62000235  VILLARREAL MARENTES JUAN MANUEL      20126
# 4  62000334       JIMENEZ RAMIREZ JORGE IVAN      20645

# %% [markdown]
# ## Checamos si los codigos postales son correctos

# %%
def check_zipcode_format(df,cp_column = 'CP'):
    ''' Checks the zipcodes column in the dataframe
        and ands a column to indicate if the zipcode has a good format
    '''
    zipcode_pattern = "^[0-9]{5}$"
    #creating a new column
    df['good_zip_code'] = False 
    df.loc[(df['Cód.postal'].str.match(zipcode_pattern)), 'good_zip_code'] = True
    

check_zipcode_format(associates, cp_column = 'Cód.postal')

# %%
associates.loc[associates.good_zip_code == False]
# Out:
# Empty DataFrame
# Columns: [Nº pers., Número de personal, Cód.postal, good_zip_code]
# Index: []

# %% [markdown]
# ## Obtenemos las coordenadas de los codigos postales

# %%
def merge_coordinates(df,cp_column = 'CP',
                     zip_codes_path = '../../data/zip_codes/codes_for_db1.csv'):

    zip_codes = pd.read_csv(zip_codes_path, index_col=0, dtype=str)
    zip_codes['CP'] = zip_codes['CP'].map(lambda x:  '0' + str(x) if (len(str(x)) == 4) else str(x) )
    zip_codes[['lat','lon']] = zip_codes[['lat','lon']].astype(float)
    zip_codes = zip_codes.drop_duplicates(subset = ['CP'], keep='first')
    merged_zipcodes = pd.merge(associates, zip_codes, left_on=[cp_column], right_on=['CP'], how = 'left')
    merged_zipcodes['has_coords'] = True
    merged_zipcodes.loc[np.isnan(merged_zipcodes['lat']), 'has_coords'] = False
    return merged_zipcodes

# %%
associates = merge_coordinates(associates,cp_column = 'Cód.postal')

# %% [markdown]
# ## Agrupamos los codigos postales similates

# %%
def group_zip_codes(df):
    group_zip_codes = df.groupby(['CP','lat','lon', 'address']).has_coords.agg('count')
    return pd.DataFrame(group_zip_codes).reset_index().rename(columns={'has_coords': 'count'})

# %%
grouped_zip_codes = group_zip_codes(associates)

# %%
def get_associates_cluster_layer(df,
                                layer_name = 'Associates Cluster',show = False):
    popups = []
    table = df.loc[df.has_coords]

    for i in range(len(table)):
        nombre = table.iloc[i]['Número de personal']
        numero = table.iloc[i]['Nº pers.']
        CP = table.iloc[i]['CP']
        text =  f'''
        <ul>
        <li><b>CP:</b> {CP}</li>
        <li><b>Nombre de personal:</b> {nombre}</li>
        <li><b>Número de personal:</b> {numero}</li>
        </ul>

        '''
        text = folium.Html(text, script=True)
        popups.append(folium.Popup(text, max_width=2650))
        
    pt_lyr = folium.FeatureGroup(name = layer_name,show=show)
    pt_lyr.add_child(MarkerCluster(locations = table[['lat', 'lon']].astype(float).values, popups= popups))
    return pt_lyr

# %%
def get_associates_heatmap_layer(df,
                                layer_name = 'Associates Heatmap', show= False):
    
    table = df.loc[df.has_coords]
    pt_lyr = folium.FeatureGroup(name = layer_name, show=show)
    pt_lyr.add_child(HeatMap(table[['lat', 'lon']].astype(float).values, max_val = 1))
    
    return pt_lyr

# %%
def get_associates_zip_codes_layer(df,
                                layer_name = 'Associates ZipCodes', show= False):
    
    pt_lyr = folium.FeatureGroup(name = layer_name,show=show)

    table = group_zip_codes(df)
    for i in range(len(table)):
        point = table.iloc[i][['lat', 'lon']].values
        CP = table.iloc[i]['CP']
        num = table.iloc[i]['count']
        text = '<p>CP: {}</p><p>Asociados: {}</p>'.format(CP, num)   
        text =  f'''
        <ul>
        <li><b>CP:</b> {CP}</li>
        <li><b>Número de Asociados:</b> {num}</li>
        </ul>

        '''
        text = folium.Html(text, script=True)
        popup = folium.Popup(text, max_width=2650)
        pt_lyr.add_child(folium.CircleMarker(point,radius = 4,
                                popup=popup,
                                fill=True, # Set fill to True
                                fill_color='white',
                                color = 'red',
                                fill_opacity=1))
    return pt_lyr

# %%
tiles_url = 'https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png'
attrb ='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>'
m = folium.Map(tiles=None)

folium.TileLayer(tiles_url,attr=attrb,name = 'Mapeo de Asociados Aguascalientes', show = True).add_to(m)

text = '<h4>Planta Bosch Aguascalientes</h4>'
text = folium.Html(text, script=True)
popup = folium.Popup(text, max_width=2650)
folium.Marker([21.967103, -102.284380], icon = folium.Icon(color='red'), popup=popup).add_to(m)

get_associates_zip_codes_layer(associates, show = True).add_to(m)
get_associates_cluster_layer(associates).add_to(m)
get_associates_heatmap_layer(associates).add_to(m)

Fullscreen(position='topleft', title='Full Screen', title_cancel='Exit Full Screen', force_separate_button=False).add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m.fit_bounds(m.get_bounds())
m
#m.save('../maps/Mapeo Asociados Aguascalientes.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Coordinates filtering

# %%
bounds = [  [21.611472417139705,-102.87322998046875],
            [21.611472417139705,-101.65924072265625],
            [22.550610920226646,-101.65924072265625],
            [ 22.550610920226646,-102.87322998046875],
            [21.611472417139705,-102.87322998046875]]

# %%
def filter_coordinates(df):
    def filter_coords(coords, bounds):
        return list(map(lambda x: ispointinside(x, bounds) if not np.isnan(x[0]) else False, coords))
    df['in_bounds'] = filter_coords(df[['lat', 'lon']].values, bounds)

# %%
filter_coordinates(associates)

# %%
tiles_url = 'https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png'
attrb ='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>'
m = folium.Map(tiles=None)

folium.TileLayer(tiles_url,attr=attrb,name = 'Mapeo de Asociados Aguascalientes', show = True).add_to(m)

text = '<h4>Planta Bosch Aguascalientes</h4>'
text = folium.Html(text, script=True)
popup = folium.Popup(text, max_width=2650)
folium.Marker([21.967103, -102.284380], icon = folium.Icon(color='red'), popup=popup).add_to(m)


table = associates.loc[associates.in_bounds]

get_associates_zip_codes_layer(table, show = True).add_to(m)
get_associates_cluster_layer(table).add_to(m)
get_associates_heatmap_layer(table).add_to(m)

Fullscreen(position='topleft', title='Full Screen', title_cancel='Exit Full Screen', force_separate_button=False).add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m.fit_bounds(m.get_bounds())
m
#m.save('../maps/Mapeo Asociados Aguascalientes.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### MONGO

# %%
import pymongo
from pymongo import MongoClient

# %%
mongoClient = MongoClient('localhost',27017)
#db = mongoClient.prueba
db = mongoClient.route_optimization_api
collection = db.associates

# %%
#associates_dict = [{"personal_number": 62000048, "name": "MALDONADO ZAMORA JOSE", "zipcode": 20324}, {"personal_number": 62000060, "name": "BENITEZ MEDINA BRAYAN ALEJANDRO", "zipcode": 20925}]

# %%
#associates_dict[0]
#collection.insert(associates_dict)

# %%
grouped_zip_codes
# Out:
#         CP        lat         lon  \
# 0    20010  21.896579 -102.316324
# 1    20020  21.900591 -102.302012
# 2    20030  21.896950 -102.291994
# 3    20040  21.888002 -102.313462
# 4    20050  21.885935 -102.302012
# ..     ...        ...         ...
# 108  78412  22.194355 -101.008170
# 109  83220  29.086492 -111.037099
# 110  98000  22.773475 -102.572467
# 111  98395  21.885256 -102.291568
# 112  98680  22.508512 -102.331322
#
#                                                address  count
# 0    Colinas de San Ignacio, 20010 Aguascalientes, ...      1
# 1    Villas de San Francisco, 20020 Aguascalientes,...      1
# 2    Fraccionamiento Industrial, 20030 Aguascalient...      2
# 3        Altavista, 20040 Aguascalientes, Ags., Mexico      3
# 4    Fuentes de la Asunción, 20050 Aguascalientes, ...      1
# ..                                                 ...    ...
# 108                        CORP CHRISTI, TX 78412, USA      1
# 109                  83220 La Manga Hermosillo Son. MX      1
# 110                             Aguascalientes, Mexico    102
# 111                             Aguascalientes, Mexico      1
# 112                             Aguascalientes, Mexico      1
#
# [113 rows x 5 columns]

# %%
for i in prueba_zip.iloc[i]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a220ac4016a0> in <module>
# ----> 1 for i in prueba_zip.iloc[i]:
#       2     print(i)
#
# NameError: name 'prueba_zip' is not defined

# %%
full_zipcodes_dict = grouped_zip_codes.to_dict(orient = 'index')

# %%
full_zipcodes_dict
# Out:
# {0: {'CP': '20010',
#   'lat': 21.8965787,
#   'lon': -102.3163244,
#   'address': 'Colinas de San Ignacio, 20010 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  1: {'CP': '20020',
#   'lat': 21.9005906,
#   'lon': -102.3020115,
#   'address': 'Villas de San Francisco, 20020 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  2: {'CP': '20030',
#   'lat': 21.8969495,
#   'lon': -102.2919936,
#   'address': 'Fraccionamiento Industrial, 20030 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  3: {'CP': '20040',
#   'lat': 21.8880018,
#   'lon': -102.3134617,
#   'address': 'Altavista, 20040 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  4: {'CP': '20050',
#   'lat': 21.8859348,
#   'lon': -102.3020115,
#   'address': 'Fuentes de la Asunción, 20050 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  5: {'CP': '20070',
#   'lat': 21.8796406,
#   'lon': -102.3077365,
#   'address': 'Desarrollo Especial Zona de la Feria, 20070 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  6: {'CP': '20115',
#   'lat': 21.9265384,
#   'lon': -102.3077365,
#   'address': 'Puerto las Hadas, 20115 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  7: {'CP': '20126',
#   'lat': 21.9334198,
#   'lon': -102.274822,
#   'address': 'Villas de Ntra. Sra. de la Asunción, 20126 Aguascalientes, Ags., Mexico',
#   'count': 58},
#  8: {'CP': '20128',
#   'lat': 22.581268,
#   'lon': -100.041568,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  9: {'CP': '20130',
#   'lat': 21.9073781,
#   'lon': -102.3091677,
#   'address': 'San José del Arenal, 20130 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  10: {'CP': '20140',
#   'lat': 21.8562758,
#   'lon': -102.267668,
#   'address': 'Morelos I, 20140 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  11: {'CP': '20149',
#   'lat': 21.905068,
#   'lon': -102.290926,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  12: {'CP': '20150',
#   'lat': 21.9050327,
#   'lon': -102.2819765,
#   'address': 'CTM, 20150 Aguascalientes, Ags., Mexico',
#   'count': 6},
#  13: {'CP': '20158',
#   'lat': 21.9083953,
#   'lon': -102.2762529,
#   'address': 'Hacienda el Cóbano, 20158 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  14: {'CP': '20160',
#   'lat': 21.8995096,
#   'lon': -102.2823342,
#   'address': 'Las Viñas, 20160 Aguascalientes, Ags., Mexico',
#   'count': 4},
#  15: {'CP': '20169',
#   'lat': 21.8966698,
#   'lon': -102.2762529,
#   'address': 'Sta Anita 2da Secc, 20169 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  16: {'CP': '20170',
#   'lat': 21.9002475,
#   'lon': -102.267668,
#   'address': 'Z. M., 20170 Aguascalientes, Ags., Mexico',
#   'count': 30},
#  17: {'CP': '20172',
#   'lat': 21.9161963,
#   'lon': -102.2505002,
#   'address': 'Claustros de Loma Dorada, 20172 Aguascalientes, Ags., Mexico',
#   'count': 13},
#  18: {'CP': '20174',
#   'lat': 21.9055619,
#   'lon': -102.2408445,
#   'address': 'Z. M., 20174 Aguascalientes, Ags., Mexico',
#   'count': 18},
#  19: {'CP': '20175',
#   'lat': 21.9150869,
#   'lon': -102.2555072,
#   'address': 'Refugio Esparza Reyes, 20175 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  20: {'CP': '20179',
#   'lat': 21.9108306,
#   'lon': -102.2633758,
#   'address': 'Progreso, 20179 Aguascalientes, Ags., Mexico',
#   'count': 16},
#  21: {'CP': '20180',
#   'lat': 21.8883064,
#   'lon': -102.2705295,
#   'address': 'Desarrollo Especial la Pona, 20180 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  22: {'CP': '20190',
#   'lat': 21.8808026,
#   'lon': -102.2533613,
#   'address': 'Ojocaliente, 20190 Aguascalientes, Ags., Mexico',
#   'count': 7},
#  23: {'CP': '20196',
#   'lat': 21.8999652,
#   'lon': -102.2519308,
#   'address': 'Municipio Libre, 20196 Aguascalientes, Ags., Mexico',
#   'count': 58},
#  24: {'CP': '20199',
#   'lat': 21.8914196,
#   'lon': -102.2583684,
#   'address': 'Fidel Velázquez, 20199 Aguascalientes, Ags., Mexico',
#   'count': 18},
#  25: {'CP': '20200',
#   'lat': 21.8529195,
#   'lon': -102.3413765,
#   'address': 'Loma Bonita, 20200 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  26: {'CP': '20206',
#   'lat': 21.852181,
#   'lon': -102.3220501,
#   'address': 'José López Portillo, 20206 Aguascalientes, Ags., Mexico',
#   'count': 7},
#  27: {'CP': '20207',
#   'lat': 21.8605713,
#   'lon': -102.3370814,
#   'address': 'Canteras de San Javier, 20207 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  28: {'CP': '20208',
#   'lat': 21.8528899,
#   'lon': -102.3320708,
#   'address': 'Villas de la Cantera, 20208 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  29: {'CP': '20210',
#   'lat': 21.8654786,
#   'lon': -102.3206187,
#   'address': 'Pirules, 20210 Aguascalientes, Ags., Mexico',
#   'count': 4},
#  30: {'CP': '20216',
#   'lat': 21.8226091,
#   'lon': -102.2757314,
#   'address': 'Villa Sur, 20216 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  31: {'CP': '20230',
#   'lat': 21.8685635,
#   'lon': -102.2991491,
#   'address': 'Desarrollo Especial Villa Asunción, 20230 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  32: {'CP': '20240',
#   'lat': 21.8725727,
#   'lon': -102.2848384,
#   'address': 'El Llanito, 20240 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  33: {'CP': '20247',
#   'lat': 21.8750649,
#   'lon': -102.2882371,
#   'address': 'San Fernando, 20247 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  34: {'CP': '20250',
#   'lat': 21.8763655,
#   'lon': -102.2733912,
#   'address': 'Jardines de la Luz, 20250 Aguascalientes, Ags., Mexico',
#   'count': 7},
#  35: {'CP': '20255',
#   'lat': 21.8761169,
#   'lon': -102.2669526,
#   'address': 'Instituto Tecnológico de Aguascalientes, 20255 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  36: {'CP': '20260',
#   'lat': 21.8707512,
#   'lon': -102.2798301,
#   'address': 'Ojo de Agua, 20260 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  37: {'CP': '20263',
#   'lat': 21.8640718,
#   'lon': -102.2419173,
#   'address': 'Solidaridad II, 20263 Aguascalientes, Ags., Mexico',
#   'count': 15},
#  38: {'CP': '20264',
#   'lat': 21.8629984,
#   'lon': -102.2562225,
#   'address': 'Vista del Sol III, 20264 Aguascalientes, Ags., Mexico',
#   'count': 8},
#  39: {'CP': '20280',
#   'lat': 21.8426137,
#   'lon': -102.2934246,
#   'address': 'Villas de Santa Rosa, 20280 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  40: {'CP': '20283',
#   'lat': 21.800923,
#   'lon': -102.285201,
#   'address': 'Aguascalientes, Mexico',
#   'count': 2},
#  41: {'CP': '20284',
#   'lat': 21.8417516,
#   'lon': -102.304874,
#   'address': 'Villas del Pilar, 20284 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  42: {'CP': '20285',
#   'lat': 21.8566546,
#   'lon': -102.3113147,
#   'address': 'Versalles 1ra Secc, 20285 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  43: {'CP': '20286',
#   'lat': 21.8406728,
#   'lon': -102.3191872,
#   'address': 'Rancho Santa Monica, 20286 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  44: {'CP': '20287',
#   'lat': 21.8501136,
#   'lon': -102.310599,
#   'address': 'Insurgentes, 20287 Aguascalientes, Ags., Mexico',
#   'count': 10},
#  45: {'CP': '20289',
#   'lat': 21.8480452,
#   'lon': -102.2991491,
#   'address': 'Pilar Blanco, 20289 Aguascalientes, Ags., Mexico',
#   'count': 6},
#  46: {'CP': '20290',
#   'lat': 21.8446176,
#   'lon': -102.2862694,
#   'address': 'Cd Industrial, 20290 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  47: {'CP': '20295',
#   'lat': 21.8261018,
#   'lon': -102.2791147,
#   'address': 'Villa Sur, 20295 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  48: {'CP': '20296',
#   'lat': 21.8247421,
#   'lon': -102.2756548,
#   'address': 'Villa Sur, 20296 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  49: {'CP': '20298',
#   'lat': 21.8517367,
#   'lon': -102.2597991,
#   'address': 'Morelos II, 20298 Aguascalientes, Ags., Mexico',
#   'count': 14},
#  50: {'CP': '20299',
#   'lat': 21.8456238,
#   'lon': -102.2533613,
#   'address': 'Lomas de Vistabella, 20299 Aguascalientes, Ags., Mexico',
#   'count': 21},
#  51: {'CP': '20300',
#   'lat': 22.0815604,
#   'lon': -102.2733912,
#   'address': 'Centro, 20300 San Francisco de los Romo, Ags., Mexico',
#   'count': 31},
#  52: {'CP': '20303',
#   'lat': 22.070052,
#   'lon': -102.2705295,
#   'address': 'San José de Buenavista, 20303 San Francisco de los Romo, Ags., Mexico',
#   'count': 1},
#  53: {'CP': '20304',
#   'lat': 22.0677705,
#   'lon': -102.2619451,
#   'address': 'San José del Barranco, 20304 San Francisco de los Romo, Ags., Mexico',
#   'count': 2},
#  54: {'CP': '20310',
#   'lat': 21.883558,
#   'lon': -102.366664,
#   'address': 'Aguascalientes, Mexico',
#   'count': 2},
#  55: {'CP': '20313',
#   'lat': 21.755147,
#   'lon': -102.349752,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  56: {'CP': '20320',
#   'lat': 21.9990958,
#   'lon': -102.2026231,
#   'address': '20320 Gral José María Morelos y Pavón, Aguascalientes, Mexico',
#   'count': 12},
#  57: {'CP': '20321',
#   'lat': 21.889133,
#   'lon': -102.253106,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  58: {'CP': '20323',
#   'lat': 21.888826,
#   'lon': -102.254092,
#   'address': 'Aguascalientes, Mexico',
#   'count': 10},
#  59: {'CP': '20324',
#   'lat': 21.8852562,
#   'lon': -102.2915677,
#   'address': 'Aguascalientes, Mexico',
#   'count': 33},
#  60: {'CP': '20326',
#   'lat': 21.8784814,
#   'lon': -102.3327866,
#   'address': 'La Soledad, 20326 Aguascalientes, Ags., Mexico',
#   'count': 3},
#  61: {'CP': '20329',
#   'lat': 21.8804461,
#   'lon': -102.3409416,
#   'address': '20329 Aguascalientes, Mexico',
#   'count': 1},
#  62: {'CP': '20330',
#   'lat': 21.917787,
#   'lon': -101.963924,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  63: {'CP': '20335',
#   'lat': 21.98464,
#   'lon': -101.944851,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  64: {'CP': '20350',
#   'lat': 22.074466,
#   'lon': -102.269644,
#   'address': 'Aguascalientes, Mexico',
#   'count': 4},
#  65: {'CP': '20355',
#   'lat': 21.9666183,
#   'lon': -102.2874383,
#   'address': 'Parque industrial de Valle de Aguascalientes, 20355 Aguascalientes, Mexico',
#   'count': 9},
#  66: {'CP': '20357',
#   'lat': 22.037314,
#   'lon': -102.14681,
#   'address': 'Aguascalientes, Mexico',
#   'count': 6},
#  67: {'CP': '20358',
#   'lat': 21.967073,
#   'lon': -102.284343,
#   'address': 'Aguascalientes, Mexico',
#   'count': 32},
#  68: {'CP': '20364',
#   'lat': 21.946503,
#   'lon': -102.2762529,
#   'address': 'Los Boyuyos, 20364 Aguascalientes, Ags., Mexico',
#   'count': 2},
#  69: {'CP': '20400',
#   'lat': 22.2282138,
#   'lon': -102.310599,
#   'address': 'El Potrero, 20400 Rincón de Romos, Ags., Mexico',
#   'count': 9},
#  70: {'CP': '20404',
#   'lat': 22.233922,
#   'lon': -102.317398,
#   'address': 'José Luís Macias, 20404 Rincón de Romos, Ags., Mexico',
#   'count': 1},
#  71: {'CP': '20406',
#   'lat': 22.2319742,
#   'lon': -102.3284919,
#   'address': 'Barrio de Chora, 20406 Rincón de Romos, Ags., Mexico',
#   'count': 1},
#  72: {'CP': '20417',
#   'lat': 22.2274686,
#   'lon': -102.3299234,
#   'address': 'Miguel Hidalgo, 20417 Rincón de Romos, Ags., Mexico',
#   'count': 2},
#  73: {'CP': '20460',
#   'lat': 22.36703,
#   'lon': -102.298375,
#   'address': 'Aguascalientes, Mexico',
#   'count': 7},
#  74: {'CP': '20468',
#   'lat': 22.362991,
#   'lon': -102.30132,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  75: {'CP': '20469',
#   'lat': 22.366173,
#   'lon': -102.302823,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  76: {'CP': '20472',
#   'lat': 22.322904,
#   'lon': -102.29272,
#   'address': 'Aguascalientes, Mexico',
#   'count': 15},
#  77: {'CP': '20478',
#   'lat': 22.387962,
#   'lon': -102.257399,
#   'address': 'Aguascalientes, Mexico',
#   'count': 3},
#  78: {'CP': '20616',
#   'lat': 22.229841,
#   'lon': -102.249961,
#   'address': 'Bryans Road, MD 20616, USA',
#   'count': 1},
#  79: {'CP': '20637',
#   'lat': 22.208532,
#   'lon': -102.249416,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  80: {'CP': '20645',
#   'lat': 22.221424,
#   'lon': -102.165838,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  81: {'CP': '20660',
#   'lat': 22.1501446,
#   'lon': -102.2869849,
#   'address': 'Vergel del Valle, 20660 Pabellón de Arteaga, Ags., Mexico',
#   'count': 1},
#  82: {'CP': '20664',
#   'lat': 22.146322,
#   'lon': -102.278712,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  83: {'CP': '20665',
#   'lat': 22.1418,
#   'lon': -102.272345,
#   'address': 'Aguascalientes, Mexico',
#   'count': 4},
#  84: {'CP': '20675',
#   'lat': 22.1462656,
#   'lon': -102.2705295,
#   'address': 'Palo Alto, 20675 Pabellón de Arteaga, Ags., Mexico',
#   'count': 1},
#  85: {'CP': '20677',
#   'lat': 22.1449608,
#   'lon': -102.2877004,
#   'address': 'Plutarco Elías Calles, 20677 Pabellón de Arteaga, Ags., Mexico',
#   'count': 1},
#  86: {'CP': '20709',
#   'lat': 22.03789,
#   'lon': -102.079063,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  87: {'CP': '20746',
#   'lat': 22.103018,
#   'lon': -102.18167,
#   'address': 'Suitland, MD 20746, USA',
#   'count': 1},
#  88: {'CP': '20750',
#   'lat': 22.123371,
#   'lon': -102.060842,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  89: {'CP': '20900',
#   'lat': 21.9676418,
#   'lon': -102.350325,
#   'address': 'El Torito, 20900 Jesús María, Ags., Mexico',
#   'count': 5},
#  90: {'CP': '20904',
#   'lat': 21.9994683,
#   'lon': -102.2953924,
#   'address': 'Centro, 20904 Jesús Gómez Portugal, Ags., Mexico',
#   'count': 1},
#  91: {'CP': '20908',
#   'lat': 21.9333909,
#   'lon': -102.2879802,
#   'address': 'Desarrollo Especial Bulevar a Zacatecas, 20908 Aguascalientes, Ags., Mexico',
#   'count': 1},
#  92: {'CP': '20909',
#   'lat': 21.9915356,
#   'lon': -102.291278,
#   'address': 'Saturnino Herrán, 20909 Jesús Gómez Portugal, Ags., Mexico',
#   'count': 10},
#  93: {'CP': '20916',
#   'lat': 21.990417,
#   'lon': -102.337213,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  94: {'CP': '20920',
#   'lat': 21.9618216,
#   'lon': -102.3449558,
#   'address': 'Zona Centro, 20920 Jesús María, Ags., Mexico',
#   'count': 5},
#  95: {'CP': '20922',
#   'lat': 21.9735448,
#   'lon': -102.3449558,
#   'address': 'El Calvario, 20922 Jesús María, Ags., Mexico',
#   'count': 1},
#  96: {'CP': '20923',
#   'lat': 21.9597598,
#   'lon': -102.3335024,
#   'address': 'La Cuesta, 20923 Jesús María, Ags., Mexico',
#   'count': 1},
#  97: {'CP': '20925',
#   'lat': 21.9525681,
#   'lon': -102.3413765,
#   'address': 'Agua Zarca, 20925 Jesús María, Ags., Mexico',
#   'count': 8},
#  98: {'CP': '20926',
#   'lat': 21.9528119,
#   'lon': -102.3478193,
#   'address': 'Vista Hermosa, 20926 Jesús María, Ags., Mexico',
#   'count': 2},
#  99: {'CP': '20928',
#   'lat': 21.966026,
#   'lon': -102.3571263,
#   'address': 'Ejidal, 20928 Jesús María, Ags., Mexico',
#   'count': 4},
#  100: {'CP': '20933',
#   'lat': 21.962935,
#   'lon': -102.344523,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  101: {'CP': '24082',
#   'lat': 22.366173,
#   'lon': -102.302823,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  102: {'CP': '70380',
#   'lat': 16.810072,
#   'lon': -95.066473,
#   'address': 'Morgan City, LA 70380, USA',
#   'count': 1},
#  103: {'CP': '78110',
#   'lat': 22.194799,
#   'lon': -100.989646,
#   'address': 'Aguascalientes, Mexico',
#   'count': 4},
#  104: {'CP': '78130',
#   'lat': 22.18042,
#   'lon': -101.014079,
#   'address': 'Aguascalientes, Mexico',
#   'count': 2},
#  105: {'CP': '78136',
#   'lat': 22.174532,
#   'lon': -101.0216865,
#   'address': 'Valle de Jacarandas 2da Secc, 78136 San Luis, S.L.P., Mexico',
#   'count': 1},
#  106: {'CP': '78137',
#   'lat': 22.175493,
#   'lon': -101.013931,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  107: {'CP': '78300',
#   'lat': 22.135142,
#   'lon': -100.964388,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  108: {'CP': '78412',
#   'lat': 22.194355,
#   'lon': -101.00817,
#   'address': 'CORP CHRISTI, TX 78412, USA',
#   'count': 1},
#  109: {'CP': '83220',
#   'lat': 29.0864916,
#   'lon': -111.0370989,
#   'address': '83220 La Manga Hermosillo Son. MX',
#   'count': 1},
#  110: {'CP': '98000',
#   'lat': 22.773475,
#   'lon': -102.572467,
#   'address': 'Aguascalientes, Mexico',
#   'count': 102},
#  111: {'CP': '98395',
#   'lat': 21.8852562,
#   'lon': -102.2915677,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1},
#  112: {'CP': '98680',
#   'lat': 22.508512,
#   'lon': -102.331322,
#   'address': 'Aguascalientes, Mexico',
#   'count': 1}}

# %%
""
for e in full_zipcodes_dict:
    try: 
        #print(zip_dict[e])
        collection.insert_one(full_zipcodes_dict[e])
    except: 
        print('ObjectId is not iterable')
""

#collection.insert_many(full_zipcodes_dict)
# Out:
# ''
